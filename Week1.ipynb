# %% [markdown]
# <a href="https://colab.research.google.com/github/nathanKiwKiw/PCVK-/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://i.ytimg.com/vi/Ie3B7Ms9klM/mqdefault.jpg",
        "https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQsdS5A0u_afxPekNoj_9YnYUIubCQ4mNaNzw&s",
        "https://awsimages.detik.net.id/community/media/visual/2022/11/07/kasus-kucing-mati-dilempar-batu-di-jakarta-kronologi-hingga-penyebab-1.jpeg?w=600&q=90",]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=320x90>
# <PIL.Image.Image image mode=RGB size=352x72>
# <PIL.Image.Image image mode=RGB size=600x272>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar =" ,tinggi, " x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar = 272  x  300
# <PIL.Image.Image image mode=RGB size=300x272>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x272>

# %%
# Convert images to RGB
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Get the dimensions of the image
height, width, _ = image.shape

# Draw a vertical line in the middle of the image
for x in range(height):
    image_3[x, int(width / 2)] = [255, 255, 255]

# Combine the images horizontally
final_frame = cv.hconcat((image_2, image_3))

# Display the final image
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x272>

# %%
# Convert images to RGB
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Get the dimensions of the image
height, width, _ = image.shape

# Draw a diagonal line
for x in range(height):
    if x < width:
        image_3[x, x] = [255, 255, 255]  # Diagonal from top-left to bottom-right
        image_3[x, width - x - 1] = [255, 255, 255]


# Combine the images horizontally
final_frame = cv.hconcat((image_2, image_3))

# Display the final image
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x272>

# %%
# Convert images to RGB
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Get the dimensions of the image
height, width, _ = image.shape

# Calculate the center of the image
center_y = height // 2

# Define margins from the edges
margin = 100  # Adjust this value to set the distance from the edges

# Calculate the start and end points of the horizontal line
start_x = margin
end_x = width - margin

# Draw the centered horizontal line
cv.line(image_3, (start_x, center_y), (end_x, center_y), (255, 255, 255), 2)  # White color, thickness 2

# Combine the images horizontally
final_frame = cv.hconcat((image_2, image_3))

# Display the final image
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x272>

# %%
# Convert images to RGB
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

# Get the dimensions of the image
height, width, _ = image.shape

# Define the dimensions of the rectangle
rect_width = width // 3  # Adjust as needed
rect_height = height // 4  # Adjust as needed

# Calculate the top-left corner of the rectangle
start_x = (width - rect_width) // 2
start_y = (height - rect_height) // 2

# Define the bottom-right corner of the rectangle
end_x = start_x + rect_width
end_y = start_y + rect_height

# Draw the centered rectangle
cv.rectangle(image_3, (start_x, start_y), (end_x, end_y), (255, 255, 255), -1)  # White color, -1 for filled

# Combine the images horizontally
final_frame = cv.hconcat((image_2, image_3))

# Display the final image
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=600x272>

# %%
urls = ["https://cdc.ui.ac.id/wp-content/uploads/2022/07/ktp.jpeg"]

for url in urls:
  image = io.imread(url)
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
  final_frame = cv.hconcat((image, image_2))
  cv2_imshow(final_frame)
  print('\n')
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /usr/lib/python3.10/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1347             try:
# -> 1348                 h.request(req.get_method(), req.selector, req.data, headers,
#    1349                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/lib/python3.10/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1282         """Send a complete request to the server."""
# -> 1283         self._send_request(method, url, body, headers, encode_chunked)
#    1284
#
# /usr/lib/python3.10/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1328             body = _encode(body, 'body')
# -> 1329         self.endheaders(body, encode_chunked=encode_chunked)
#    1330
#
# ...
